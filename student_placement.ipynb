# %%
import pandas as pd

# %%
df=pd.read_csv("student_placement_anxiety_dataset.csv")

# %%
df.head()
# Out:
#   Student_ID Branch  CGPA  Internships  Mock_Test_Score  \
# 0       S001     IT  8.24            0               92
# 1       S002    CSE  8.37            4               50
# 2       S003     IT  7.77            0               80
# 3       S004    ECE  6.97            0               55
# 4       S005    CSE  6.75            2               51
#
#    Coding_Hours_Per_Week  Resume_Score Anxiety_Level  Expected_Package_LPA  \
# 0                     11            65           Low                  11.8
# 1                     21            77           Low                   5.6
# 2                      9            95          High                   8.4
# 3                     25            77          High                   6.3
# 4                      5            74          High                   7.3
#
#   Placement_Status
# 0           Placed
# 1           Placed
# 2       Not Placed
# 3       Not Placed
# 4       Not Placed

# %%
df.shape
# Out:
# (100, 10)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Branch', 'CGPA', 'Internships', 'Mock_Test_Score',
#        'Coding_Hours_Per_Week', 'Resume_Score', 'Anxiety_Level',
#        'Expected_Package_LPA', 'Placement_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             100 non-null    object
#  1   Branch                 100 non-null    object
#  2   CGPA                   100 non-null    float64
#  3   Internships            100 non-null    int64
#  4   Mock_Test_Score        100 non-null    int64
#  5   Coding_Hours_Per_Week  100 non-null    int64
#  6   Resume_Score           100 non-null    int64
#  7   Anxiety_Level          100 non-null    object
#  8   Expected_Package_LPA   100 non-null    float64
#  9   Placement_Status       100 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 7.9+ KB

# %%
df2 = pd.read_csv("student_performance.csv")

# %%
df2.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
df2.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   student_id               1000000 non-null  int64
#  1   weekly_self_study_hours  1000000 non-null  float64
#  2   attendance_percentage    1000000 non-null  float64
#  3   class_participation      1000000 non-null  float64
#  4   total_score              1000000 non-null  float64
#  5   grade                    1000000 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 45.8+ MB

# %%
df2.shape
# Out:
# (1000000, 6)

# %%
df2 = df2.rename(columns={"student id": "Student_ID"})

# %%
df["Student_ID"] = df["Student_ID"].astype(str).str.replace("S","", regex=False).astype(int)

# %%
merged_df = pd.merge(df, df2, 
                     left_on="Student_ID", 
                     right_on="student_id")

# %%
merged_df.shape
# Out:
# (100, 16)

# %%
merged_df.head()
# Out:
#    Student_ID Branch  CGPA  Internships  Mock_Test_Score  \
# 0           1     IT  8.24            0               92
# 1           2    CSE  8.37            4               50
# 2           3     IT  7.77            0               80
# 3           4    ECE  6.97            0               55
# 4           5    CSE  6.75            2               51
#
#    Coding_Hours_Per_Week  Resume_Score Anxiety_Level  Expected_Package_LPA  \
# 0                     11            65           Low                  11.8
# 1                     21            77           Low                   5.6
# 2                      9            95          High                   8.4
# 3                     25            77          High                   6.3
# 4                      5            74          High                   7.3
#
#   Placement_Status  student_id  weekly_self_study_hours  \
# 0           Placed           1                     18.5
# ...

# %%
merged_df.columns
# Out:
# Index(['Student_ID', 'Branch', 'CGPA', 'Internships', 'Mock_Test_Score',
#        'Coding_Hours_Per_Week', 'Resume_Score', 'Anxiety_Level',
#        'Expected_Package_LPA', 'Placement_Status', 'student_id',
#        'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Student_ID               100 non-null    int64
#  1   Branch                   100 non-null    object
#  2   CGPA                     100 non-null    float64
#  3   Internships              100 non-null    int64
#  4   Mock_Test_Score          100 non-null    int64
#  5   Coding_Hours_Per_Week    100 non-null    int64
#  6   Resume_Score             100 non-null    int64
#  7   Anxiety_Level            100 non-null    object
#  8   Expected_Package_LPA     100 non-null    float64
#  9   Placement_Status         100 non-null    object
#  10  student_id               100 non-null    int64
#  11  weekly_self_study_hours  100 non-null    float64
#  12  attendance_percentage    100 non-null    float64
#  13  class_participation      100 non-null    float64
# ...

# %%
merged_df.isnull()
# Out:
#     Student_ID  Branch   CGPA  Internships  Mock_Test_Score  \
# 0        False   False  False        False            False
# 1        False   False  False        False            False
# 2        False   False  False        False            False
# 3        False   False  False        False            False
# 4        False   False  False        False            False
# ..         ...     ...    ...          ...              ...
# 95       False   False  False        False            False
# 96       False   False  False        False            False
# 97       False   False  False        False            False
# 98       False   False  False        False            False
# 99       False   False  False        False            False
#
#     Coding_Hours_Per_Week  Resume_Score  Anxiety_Level  Expected_Package_LPA  \
# 0                   False         False          False                 False
# 1                   False         False          False                 False
# ...

# %%
merged_df.isnull().sum()
# Out:
# Student_ID                 0
# Branch                     0
# CGPA                       0
# Internships                0
# Mock_Test_Score            0
# Coding_Hours_Per_Week      0
# Resume_Score               0
# Anxiety_Level              0
# Expected_Package_LPA       0
# Placement_Status           0
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      0
# dtype: int64

# %%
merged_df.describe()
# Out:
#        Student_ID        CGPA  Internships  Mock_Test_Score  \
# count  100.000000  100.000000   100.000000        100.00000
# mean    50.500000    7.705100     1.860000         67.53000
# std     29.011492    1.004176     1.333485         13.74549
# min      1.000000    6.020000     0.000000         45.00000
# 25%     25.750000    6.947500     1.000000         57.00000
# 50%     50.500000    7.770000     2.000000         67.00000
# 75%     75.250000    8.510000     3.000000         78.25000
# max    100.000000    9.500000     4.000000         92.00000
#
#        Coding_Hours_Per_Week  Resume_Score  Expected_Package_LPA  student_id  \
# count             100.000000    100.000000             100.00000  100.000000
# mean               13.260000     74.550000               8.85600   50.500000
# std                 6.568397     12.808122               3.30776   29.011492
# min                 3.000000     50.000000               3.30000    1.000000
# ...

# %%
df3=pd.read_csv("Math-Students.csv")

# %%
df3.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df3.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df3.shape
# Out:
# (399, 33)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      399 non-null    object
#  1   sex         399 non-null    object
#  2   age         399 non-null    int64
#  3   address     399 non-null    object
#  4   famsize     399 non-null    object
#  5   Pstatus     399 non-null    object
#  6   Medu        399 non-null    int64
#  7   Fedu        399 non-null    int64
#  8   Mjob        399 non-null    object
#  9   Fjob        399 non-null    object
#  10  reason      399 non-null    object
#  11  guardian    399 non-null    object
#  12  traveltime  399 non-null    int64
#  13  studytime   399 non-null    int64
#  14  failures    399 non-null    int64
#  15  schoolsup   399 non-null    object
#  16  famsup      399 non-null    object
#  17  paid        399 non-null    object
#  18  activities  399 non-null    object
# ...

# %%
df3.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df3.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  399.000000  399.000000  399.000000  399.000000  399.000000  399.000000
# mean    16.709273    2.761905    2.536341    1.443609    2.035088    0.330827
# std      1.278225    1.096340    1.092716    0.695429    0.835020    0.740655
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    3.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.500000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  399.000000  399.000000  399.000000  399.000000  399.000000  399.000000
# mean     3.954887    3.233083    3.097744    1.476190    2.288221    3.558897
# ...

# %%
df3.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     399  399  399.000000     399     399     399  399.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     311     285     358         NaN
# mean      NaN  NaN   16.709273     NaN     NaN     NaN    2.761905
# std       NaN  NaN    1.278225     NaN     NaN     NaN    1.096340
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   399.000000    399    399  ...  399.000000  399.000000  399.000000
# ...

# %%
df3['sex'].value_counts()
# Out:
# sex
# F    208
# M    191
# Name: count, dtype: int64

# %% [markdown]
# df3['school'].value_counts()

# %%
df3['school'].value_counts()
# Out:
# school
# GP    349
# MS     50
# Name: count, dtype: int64

# %%
df3['famsize'].value_counts()
# Out:
# famsize
# GT3    285
# LE3    114
# Name: count, dtype: int64

# %%
df3['Mjob'].value_counts()
# Out:
# Mjob
# other       141
# services    103
# teacher      62
# at_home      59
# health       34
# Name: count, dtype: int64

# %%
df3['Fjob'].value_counts()
# Out:
# Fjob
# other       218
# services    113
# teacher      29
# at_home      21
# health       18
# Name: count, dtype: int64

# %%
df3['Pstatus'].value_counts()
# Out:
# Pstatus
# T    358
# A     41
# Name: count, dtype: int64

# %%
df3[['age', 'Medu', 'Fedu']].describe()
# Out:
#               age        Medu        Fedu
# count  399.000000  399.000000  399.000000
# mean    16.709273    2.761905    2.536341
# std      1.278225    1.096340    1.092716
# min     15.000000    0.000000    0.000000
# 25%     16.000000    2.000000    2.000000
# 50%     17.000000    3.000000    3.000000
# 75%     18.000000    4.000000    3.500000
# max     22.000000    4.000000    4.000000

# %%
df3['age'].value_counts()
# Out:
# age
# 16    104
# 17     99
# 18     84
# 15     82
# 19     25
# 20      3
# 22      1
# 21      1
# Name: count, dtype: int64

# %%
df3['Medu'].value_counts()
# Out:
# Medu
# 4    135
# 2    103
# 3     99
# 1     59
# 0      3
# Name: count, dtype: int64

# %%
df3['Fedu'].value_counts()
# Out:
# Fedu
# 2    115
# 4    100
# 3    100
# 1     82
# 0      2
# Name: count, dtype: int64

# %%
merged_df["Placement_Status"].value_counts()
# Out:
# Placement_Status
# Not Placed    57
# Placed        43
# Name: count, dtype: int64

# %%
merged_df.groupby("Placement_Status")["CGPA"].mean()
# Out:
# Placement_Status
# Not Placed    7.218070
# Placed        8.350698
# Name: CGPA, dtype: float64

# %%
merged_df.groupby("Placement_Status")["Internships"].mean()
# Out:
# Placement_Status
# Not Placed    1.824561
# Placed        1.906977
# Name: Internships, dtype: float64

# %%
merged_df.corr(numeric_only=True)
# Out:
#                          Student_ID      CGPA  Internships  Mock_Test_Score  \
# Student_ID                 1.000000 -0.139233     0.024543         0.071874
# CGPA                      -0.139233  1.000000    -0.085079         0.107685
# Internships                0.024543 -0.085079     1.000000         0.032745
# Mock_Test_Score            0.071874  0.107685     0.032745         1.000000
# Coding_Hours_Per_Week     -0.088681 -0.105090     0.164497        -0.076500
# Resume_Score               0.017085  0.032349     0.131116        -0.039368
# Expected_Package_LPA      -0.121848 -0.011187     0.065000         0.123041
# student_id                 1.000000 -0.139233     0.024543         0.071874
# weekly_self_study_hours    0.049390  0.141393    -0.199612        -0.033877
# attendance_percentage     -0.092810  0.102161    -0.072089         0.223830
# class_participation        0.039213  0.031837     0.068022        -0.007838
# ...

# %%
merged_df.to_csv("final_placement_dataset.csv", index=False)
